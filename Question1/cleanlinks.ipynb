# %% [markdown]
# NAME = "Xudong Guo"
#
# Description: This file is used to clean up extra links not needed.
#
# Input: 'combined_with_frequency.csv'
# Output: 'cleaned_link.csv'

# %%
import pandas as pd
import ast

# %%
file = pd.read_csv('combined_with_frequency.csv')

# %%
file
# Out:
#      kanji  strokes  frequency        grade jlpt  \
# 0        亜      7.0     1509.0  junior high   N1
# 1        哀      9.0     1715.0  junior high   N1
# 2        挨     10.0     2258.0  junior high  NaN
# 3        愛     13.0      640.0      grade 4   N3
# 4        曖     17.0        NaN  junior high  NaN
# ...    ...      ...        ...          ...  ...
# 2131     脇     10.0     1806.0  junior high  NaN
# 2132     惑     12.0      777.0  junior high   N1
# 2133     枠      8.0      922.0  junior high   N1
# 2134     湾     12.0      545.0  junior high   N2
# 2135     腕     12.0     1163.0  junior high   N2
#
#                                                   parts  \
# 0     {'一': 'http:////jisho.org/search/%E4%B8%80%20%...
# 1     {'亠': 'http:////jisho.org/search/%E4%BA%A0%20%...
# 2     {'厶': 'http:////jisho.org/search/%E5%8E%B6%20%...
# 3     {'冖': 'http:////jisho.org/search/%E5%86%96%20%...
# 4     {'冖': 'http:////jisho.org/search/%E5%86%96%20%...
# ...

# %%
d = ast.literal_eval(file['parts'][0])

# %%
newcol = [None] * len(file['parts'])
for i in range(0,len(file['parts'])):
    newcol[i] = list(ast.literal_eval(file['parts'][i]).keys())

# %%
len(newcol)
# Out:
# 2136

# %%
file['parts'] = newcol

# %%
file
# Out:
#      kanji  strokes  frequency        grade jlpt            parts  \
# 0        亜      7.0     1509.0  junior high   N1        [一, ｜, 口]
# 1        哀      9.0     1715.0  junior high   N1        [亠, 口, 衣]
# 2        挨     10.0     2258.0  junior high  NaN     [厶, 扎, 矢, 乞]
# 3        愛     13.0      640.0      grade 4   N3     [冖, 夂, 心, 爪]
# 4        曖     17.0        NaN  junior high  NaN  [冖, 夂, 心, 日, 爪]
# ...    ...      ...        ...          ...  ...              ...
# 2131     脇     10.0     1806.0  junior high  NaN           [力, 月]
# 2132     惑     12.0      777.0  junior high   N1        [口, 心, 戈]
# 2133     枠      8.0      922.0  junior high   N1        [十, 九, 木]
# 2134     湾     12.0      545.0  junior high   N2        [亠, 弓, 汁]
# 2135     腕     12.0     1163.0  junior high   N2     [卩, 夕, 宀, 月]
#
#                      radicals  \
# 0                {'二': 'two'}
# 1     {'口': 'mouth, opening'}
# 2          {'手 (扌龵)': 'hand'}
# 3       {'心 (忄, ⺗)': 'heart'}
# ...

# %%
newcol = [None] * len(file['on_readings'])
for i in range(0,len(file['on_readings'])):
    try:
        newcol[i] = list(ast.literal_eval(file['on_readings'][i]).keys())
    except:
        continue
len(newcol)
# Out:
# 2136

# %%
file['on_readings']  = newcol

# %%
file
# Out:
#      kanji  strokes  frequency        grade jlpt            parts  \
# 0        亜      7.0     1509.0  junior high   N1        [一, ｜, 口]
# 1        哀      9.0     1715.0  junior high   N1        [亠, 口, 衣]
# 2        挨     10.0     2258.0  junior high  NaN     [厶, 扎, 矢, 乞]
# 3        愛     13.0      640.0      grade 4   N3     [冖, 夂, 心, 爪]
# 4        曖     17.0        NaN  junior high  NaN  [冖, 夂, 心, 日, 爪]
# ...    ...      ...        ...          ...  ...              ...
# 2131     脇     10.0     1806.0  junior high  NaN           [力, 月]
# 2132     惑     12.0      777.0  junior high   N1        [口, 心, 戈]
# 2133     枠      8.0      922.0  junior high   N1        [十, 九, 木]
# 2134     湾     12.0      545.0  junior high   N2        [亠, 弓, 汁]
# 2135     腕     12.0     1163.0  junior high   N2     [卩, 夕, 宀, 月]
#
#                      radicals on_readings  \
# 0                {'二': 'two'}         [ア]
# 1     {'口': 'mouth, opening'}        [アイ]
# 2          {'手 (扌龵)': 'hand'}        [アイ]
# ...

# %%
newcol = [None] * len(file['kun_readings'])
for i in range(0,len(file['kun_readings'])):
    try:
        newcol[i] = list(ast.literal_eval(file['kun_readings'][i]).keys())
    except:
        continue
len(newcol)
# Out:
# 2136

# %%
file['kun_readings'] = newcol

# %%
file
# Out:
#      kanji  strokes  frequency        grade jlpt            parts  \
# 0        亜      7.0     1509.0  junior high   N1        [一, ｜, 口]
# 1        哀      9.0     1715.0  junior high   N1        [亠, 口, 衣]
# 2        挨     10.0     2258.0  junior high  NaN     [厶, 扎, 矢, 乞]
# 3        愛     13.0      640.0      grade 4   N3     [冖, 夂, 心, 爪]
# 4        曖     17.0        NaN  junior high  NaN  [冖, 夂, 心, 日, 爪]
# ...    ...      ...        ...          ...  ...              ...
# 2131     脇     10.0     1806.0  junior high  NaN           [力, 月]
# 2132     惑     12.0      777.0  junior high   N1        [口, 心, 戈]
# 2133     枠      8.0      922.0  junior high   N1        [十, 九, 木]
# 2134     湾     12.0      545.0  junior high   N2        [亠, 弓, 汁]
# 2135     腕     12.0     1163.0  junior high   N2     [卩, 夕, 宀, 月]
#
#                      radicals on_readings                    kun_readings  \
# 0                {'二': 'two'}         [ア]                           [つ.ぐ]
# ...

# %%
file.to_csv('cleaned_link.csv', index=False)
