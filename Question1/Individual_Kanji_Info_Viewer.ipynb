# %%
# Creator Name
CREATOR_NAME = "Jingheng Wang"

# %% [markdown]
# This file is not for answering the question. It is used as a friendly viewer of the csv file, that can display the comprehensive information of a single kanji to human-read-friendly formats.
#
# Before use, please make sure the "cleaned_link.csv" file is under the same directory with this Jupyter Notebook.
#
# **If it is in another directory, you need to change the path in the following cell.**
#
# To use:
# 1. Run the following two cells to initialize.
# 2. In the "query_kanji" cell, you could replace that kanji with any kanji that you want to query. Run that cell.
# 3. Run the following grid of that kanji cell will display all of the related information about that kanji in the csv file.
#
# Note: Running the last cell will display the raw DataFrame read from csv.

# %%
# Modify me if the csv file is not in the same directory with this notebook
csv_path = "cleaned_link.csv"

# %%
# Initialization
import numpy as np
import pandas as pd
import ast

_df_ = pd.read_csv(csv_path)

def get_kanji_info(kanji = '日'):
    return _df_[_df_["kanji"] == kanji]

def row_info_to_print(_slice_ = get_kanji_info('日')):
    # The index of that row
    ind = _slice_.index
    # That index in integer type
    intind = _slice_.index[0].astype(int)
    
    # Print the Kanji itself
    print(_slice_.loc[ind,"kanji"][intind])
    # Print the number of strokes
    print("Number of Strokes: {}".format(_slice_.loc[ind,"strokes"][intind].astype(int)))
    # Print the readings
    if (type(_slice_.loc[ind, "on_readings"][intind]) is str):
        temp = _slice_.loc[ind,"on_readings"][intind]
        res = list(ast.literal_eval(temp))
        print("on-readings: {}". format(res))
    if (type(_slice_.loc[ind, "kun_readings"][intind]) is str):
        temp = _slice_.loc[ind,"kun_readings"][intind]
        res = list(ast.literal_eval(temp))
        print("kun-readings: {}". format(res))
    # Print the meanings
    if (type(_slice_.loc[ind, "main_meaning"][intind]) is str):
        temp = _slice_.loc[ind,"main_meaning"][intind]
        res = list(ast.literal_eval(temp))
        print("Meaning(s): {}". format(res))
    
    # Grade Difficulty
    if (type(_slice_.loc[ind,"grade"][intind]) is str):
        print("Teach in grade: {}".format(_slice_.loc[ind,"grade"][intind]))
    if (type(_slice_.loc[ind,"jlpt"][intind]) is str):
        print("JLPT Level: {}".format(_slice_.loc[ind,"jlpt"][intind]))
    
    # Parts and Radicals
    if (type(_slice_.loc[ind, "parts"][intind]) is str):
        temp = _slice_.loc[ind,"parts"][intind]
        res = list(ast.literal_eval(temp))
        print("Contains parts: {}". format(res))
    if (type(_slice_.loc[ind, "radicals"][intind]) is str):
        temp = _slice_.loc[ind,"radicals"][intind]
        res = list(ast.literal_eval(temp).keys())
        print("Contains radical: {}". format(res))
        
    # Additional Info: Wanikani level and Genki Lesson
    if (~np.isnan(_slice_.loc[ind,"wanikani_level"][intind])):
        print("Wanikani Level: {}".format(_slice_.loc[ind,"wanikani_level"][intind].astype(int)))
    if (~np.isnan(_slice_.loc[ind,"Genki_Level"][intind])):
        print('Teach in Book "Genki": Lesson {}'.format(_slice_.loc[ind,"Genki_Level"][intind].astype(int)))
        
    if (type(_slice_.loc[ind, "on_readings_compounds"][intind]) is str):
        temp = _slice_.loc[ind,"on_readings_compounds"][intind]
        res = list(ast.literal_eval(temp))
        print('On-reading compounds:')
        for x in res:
            print("   {}".format(x))
    if (type(_slice_.loc[ind, "kun_readings_compounds"][intind]) is str):
        temp = _slice_.loc[ind,"kun_readings_compounds"][intind]
        res = list(ast.literal_eval(temp))
        print('Kun-reading compounds:')
        for x in res:
            print("   {}".format(x))
        
    return

# %%
# Change the kanji here if you want, and run me!
query_kanji = "水"

# Here are a number of sample kanjis if you want to test but cannot type one:
# 水 (water)
# 木 (wood)
# 金 (metal)
# 二 (two)
# 米 (rice / United States)
# 闇 (dark)

# %%
# Run me to display the information!
row_info_to_print(get_kanji_info(query_kanji))
sl = get_kanji_info(query_kanji)
# Out:
# 水
# Number of Strokes: 4
# on-readings: ['スイ']
# kun-readings: ['みず', 'みず-']
# Meaning(s): ['water']
# Teach in grade: grade 1
# JLPT Level: N5
# Contains parts: ['水']
# Contains radical: ['水 (氵, 氺)']
# Wanikani Level: 2
# Teach in Book "Genki": Lesson 4
# On-reading compounds:
#    水  【スイ】  Wednesday, shaved ice (served with flavored syrup), water (fifth of the five elements)
#    水位  【スイイ】  water level
#    用水  【ヨウスイ】  irrigation water, water for fire, city water, cistern water
#    浄水  【ジョウスイ】  clean water
# Kun-reading compounds:
#    水  【みず】  water (esp. cool, fresh water, e.g. drinking water), fluid (esp. in an animal tissue), liquid, flood, floodwaters, water offered to wrestlers just prior to a bout, break granted to wrestlers engaged in a prolonged bout
#    水揚げ  【みずあげ】  landing, unloading (e.g. a ship), catch (of fish), takings, sales (of a shop), defloration (e.g. of a geisha), preservation (of cut flowers, in ikebana)
#    飲み水  【のみみず】  drinking water, potable water
#    呼び水  【よびみず】  pump-priming, rousing, stimulation

# %%
# Raw Dataframe
_df_
# Out:
#      kanji  strokes  frequency        grade jlpt  \
# 0        亜      7.0     1509.0  junior high   N1
# 1        哀      9.0     1715.0  junior high   N1
# 2        挨     10.0     2258.0  junior high  NaN
# 3        愛     13.0      640.0      grade 4   N3
# 4        曖     17.0        NaN  junior high  NaN
# 5        悪     11.0      530.0      grade 3   N4
# 6        握     12.0     1003.0  junior high   N1
# 7        圧      5.0      718.0      grade 5   N2
# 8        扱      6.0     1057.0  junior high   N1
# 9        宛      8.0        NaN  junior high  NaN
# 10       嵐     12.0     1910.0  junior high   N1
# 11       安      6.0      144.0      grade 3   N4
# 12       案     10.0      206.0      grade 4   N1
# 13       暗     13.0     1040.0      grade 3   N3
# 14       以      5.0      126.0      grade 4   N4
# 15       衣      6.0     1214.0      grade 4   N2
# 16       位      7.0      276.0      grade 4   N3
# 17       囲      7.0      771.0      grade 4   N2
# 18       医      7.0      437.0      grade 3   N4
# 19       依      8.0      906.0  junior high   N2
# 20       委      8.0      187.0      grade 3   N2
# 21       威      9.0     1103.0  junior high   N1
# 22       為      9.0      831.0  junior high   N1
# 23       畏      9.0     2389.0  junior high  NaN
# 24       胃      9.0     1647.0      grade 4   N2
# 25       尉     11.0     2007.0  junior high   N1
# 26       異     11.0      631.0      grade 6   N1
# 27       移     11.0      448.0      grade 5   N2
# 28       萎     11.0        NaN  junior high  NaN
# 29       偉     12.0     1639.0  junior high   N3
# ...    ...      ...        ...          ...  ...
# 2106     廉     13.0     2066.0  junior high   N1
# 2107     練     14.0      788.0      grade 3   N2
# 2108     錬     16.0     2221.0  junior high   N1
# 2109     呂      7.0     2055.0  junior high   N1
# 2110     炉      8.0     1359.0  junior high   N1
# 2111     賂     13.0        NaN  junior high  NaN
# 2112     路     13.0      529.0      grade 3   N3
# 2113     露     21.0      928.0  junior high   N1
# 2114     老      6.0      803.0      grade 4   N3
# 2115     労      7.0      398.0      grade 4   N3
# 2116     弄      7.0        NaN  junior high  NaN
# 2117     郎      9.0      569.0  junior high   N1
# 2118     朗     10.0     1374.0      grade 6   N1
# 2119     浪     10.0     1508.0  junior high   N1
# 2120     廊     12.0     1598.0  junior high   N1
# 2121     楼     13.0     2173.0  junior high   N1
# 2122     漏     14.0     1298.0  junior high   N1
# 2123     籠     22.0        NaN  junior high  NaN
# 2124     六      4.0       93.0      grade 1   N5
# 2125     録     16.0      546.0      grade 4   N2
# 2126     麓     19.0     2366.0  junior high  NaN
# 2127     論     15.0      227.0      grade 6   N3
# 2128     和      8.0      124.0      grade 3   N3
# 2129     話     13.0      134.0      grade 2   N5
# 2130     賄     13.0     1282.0  junior high   N1
# 2131     脇     10.0     1806.0  junior high  NaN
# 2132     惑     12.0      777.0  junior high   N1
# 2133     枠      8.0      922.0  junior high   N1
# 2134     湾     12.0      545.0  junior high   N2
# 2135     腕     12.0     1163.0  junior high   N2
#
#                                          parts                     radicals  \
# 0                              ['一', '｜', '口']                 {'二': 'two'}
# 1                              ['亠', '口', '衣']      {'口': 'mouth, opening'}
# 2                         ['厶', '扎', '矢', '乞']           {'手 (扌龵)': 'hand'}
# 3                         ['冖', '夂', '心', '爪']        {'心 (忄, ⺗)': 'heart'}
# 4                    ['冖', '夂', '心', '日', '爪']            {'日': 'sun, day'}
# 5                         ['一', '｜', '口', '心']        {'心 (忄, ⺗)': 'heart'}
# 6                    ['厶', '土', '尸', '扎', '至']           {'手 (扌龵)': 'hand'}
# 7                                   ['厂', '土']               {'土': 'earth'}
# 8                                   ['扎', '及']           {'手 (扌龵)': 'hand'}
# 9                              ['卩', '夕', '宀']                {'宀': 'roof'}
# 10                                  ['山', '風']            {'山': 'mountain'}
# 11                                  ['女', '宀']                {'宀': 'roof'}
# 12                             ['女', '宀', '木']                {'木': 'tree'}
# 13                             ['日', '立', '音']            {'日': 'sun, day'}
# 14                             ['｜', '丶', '人']      {'人 (亻)': 'man, human'}
# 15                                  ['亠', '衣']         {'衣 (衤)': 'clothes'}
# 16                                  ['化', '立']      {'人 (亻)': 'man, human'}
# 17                                  ['囗', '井']           {'囗': 'enclosure'}
# 18                             ['匚', '矢', '乞']    {'匸': 'hiding enclosure'}
# 19                             ['亠', '化', '衣']      {'人 (亻)': 'man, human'}
# 20                                  ['女', '禾']       {'女': 'woman, female'}
# 21                        ['ノ', '厂', '女', '戈']       {'女': 'woman, female'}
# 22              ['ユ', '丶', 'ノ', '并', '勹', '杰']            {'爪 (爫)': 'claw'}
# 23                             ['一', '田', '衣']               {'田': 'field'}
# 24                                  ['月', '田']            {'肉 (⺼)': 'meat'}
# 25                   ['二', '寸', '小', '尸', '示']         {'寸': 'thumb, inch'}
# 26                        ['一', 'ハ', '井', '田']               {'田': 'field'}
# 27                                  ['夕', '禾']               {'禾': 'grain'}
# 28                             ['女', '艾', '禾']           {'艸 (艹)': 'grass'}
# 29                             ['化', '口', '韋']      {'人 (亻)': 'man, human'}
# ...                                        ...                          ...
# 2106                 ['｜', 'ハ', '并', '广', 'ヨ']      {'广': 'house on cliff'}
# 2107  ['｜', 'ハ', '小', '幺', '日', '木', '田', '糸']            {'糸 (糹)': 'silk'}
# 2108  ['一', '｜', 'ハ', '并', '日', '木', '田', '金']     {'金 (釒)': 'metal, gold'}
# 2109                                ['ノ', '口']      {'口': 'mouth, opening'}
# 2110                      ['一', '尸', '戸', '火']            {'火 (灬)': 'fire'}
# 2111                 ['ハ', '口', '夂', '目', '貝']               {'貝': 'shell'}
# 2112                      ['口', '夂', '止', '足']            {'足 (⻊)': 'foot'}
# 2113                 ['口', '夂', '止', '足', '雨']                {'雨': 'rain'}
# 2114                                ['匕', '老']             {'老 (耂)': 'old'}
# 2115                           ['冖', '力', '尚']        {'力': 'power, force'}
# 2116                                ['廾', '王']     {'玉 (王)': 'jade (king)'}
# 2117                                ['邦', '艮']  {'邑 (阝)': 'town (阝 right)'}
# 2118                                ['月', '艮']         {'月': 'moon, month'}
# 2119                                ['汁', '艮']        {'水 (氵, 氺)': 'water'}
# 2120                           ['广', '邦', '艮']      {'广': 'house on cliff'}
# 2121                           ['女', '木', '米']                {'木': 'tree'}
# 2122                           ['尸', '汁', '雨']        {'水 (氵, 氺)': 'water'}
# 2123                      ['月', '立', '竹', '乞']          {'竹 (⺮)': 'bamboo'}
# 2124                                ['亠', 'ハ']               {'八': 'eight'}
# 2125                      ['ヨ', '水', '金', '隶']     {'金 (釒)': 'metal, gold'}
# 2126                      ['广', '木', '比', '鹿']                {'鹿': 'deer'}
# 2127            ['一', '｜', '个', '廾', '冊', '言']          {'言 (訁)': 'speech'}
# 2128                                ['口', '禾']      {'口': 'mouth, opening'}
# 2129                           ['口', '舌', '言']          {'言 (訁)': 'speech'}
# 2130            ['一', 'ノ', 'ハ', '月', '目', '貝']               {'貝': 'shell'}
# 2131                                ['力', '月']            {'肉 (⺼)': 'meat'}
# 2132                           ['口', '心', '戈']        {'心 (忄, ⺗)': 'heart'}
# 2133                           ['十', '九', '木']                {'木': 'tree'}
# 2134                           ['亠', '弓', '汁']        {'水 (氵, 氺)': 'water'}
# 2135                      ['卩', '夕', '宀', '月']            {'肉 (⺼)': 'meat'}
#
#              on_readings                                       kun_readings  \
# 0                  ['ア']                                            ['つ.ぐ']
# 1                 ['アイ']                         ['あわ.れ', 'あわ.れむ', 'かな.しい']
# 2                 ['アイ']                                           ['ひら.く']
# 3                 ['アイ']           ['いと.しい', 'かな.しい', 'め.でる', 'お.しむ', 'まな']
# 4                 ['アイ']                                           ['くら.い']
# 5            ['アク', 'オ']  ['わる.い', 'わる-', 'あ.し', 'にく.い', '-にく.い', 'ああ', ...
# 6                 ['アク']                                           ['にぎ.る']
# 7     ['アツ', 'エン', 'オウ']                   ['お.す', 'へ.す', 'おさ.える', 'お.さえる']
# 8          ['ソウ', 'キュウ']                 ['あつか.い', 'あつか.う', 'あつか.る', 'こ.く']
# 9                 ['エン']                    ['あ.てる', '-あて', '-づつ', 'あたか.も']
# 10                ['ラン']                                            ['あらし']
# 11                ['アン']                   ['やす.い', 'やす.まる', 'やす', 'やす.らか']
# 12                ['アン']                                            ['つくえ']
# 13                ['アン']                           ['くら.い', 'くら.む', 'くれ.る']
# 14                 ['イ']                                           ['もっ.て']
# 15            ['イ', 'エ']                                ['ころも', 'きぬ', '-ぎ']
# 16                 ['イ']                                     ['くらい', 'ぐらい']
# 17                 ['イ']                           ['かこ.む', 'かこ.う', 'かこ.い']
# 18                 ['イ']                            ['い.やす', 'い.する', 'くすし']
# 19            ['イ', 'エ']                                            ['よ.る']
# 20                 ['イ']                                          ['ゆだ.ねる']
# 21                 ['イ']                          ['おど.す', 'おど.し', 'おど.かす']
# 22                 ['イ']    ['ため', 'な.る', 'な.す', 'す.る', 'たり', 'つく.る', 'なり']
# 23                 ['イ']                ['おそ.れる', 'かしこま.る', 'かしこ', 'かしこ.し']
# 24                   NaN                                              ['イ']
# 25                   NaN                                       ['イ', 'ジョウ']
# 26                 ['イ']                               ['こと', 'こと.なる', 'け']
# 27                 ['イ']                                   ['うつ.る', 'うつ.す']
# 28                 ['イ']            ['な', 'しお.れる', 'しな.びる', 'しぼ.む', 'な.える']
# 29                 ['イ']                                           ['えら.い']
# ...                  ...                                                ...
# 2106                 NaN                                             ['レン']
# 2107              ['レン']                                     ['ね.る', 'ね.り']
# 2108              ['レン']                                            ['ね.る']
# 2109         ['ロ', 'リョ']                                            ['せぼね']
# 2110               ['ロ']                                            ['いろり']
# 2111               ['ロ']                                 ['まいな.い', 'まいな.う']
# 2112          ['ロ', 'ル']                                       ['-じ', 'みち']
# 2113         ['ロ', 'ロウ']                                             ['つゆ']
# 2114              ['ロウ']                                   ['お.いる', 'ふ.ける']
# 2115              ['ロウ']  ['ろう.する', 'いたわ.る', 'いた.ずき', 'ねぎら', 'つか.れる', 'ね...
# 2116         ['ロウ', 'ル']  ['いじく.る', 'ろう.する', 'いじ.る', 'ひねく.る', 'たわむ.れる', ...
# 2117       ['ロウ', 'リョウ']                                            ['おとこ']
# 2118              ['ロウ']                                 ['ほが.らか', 'あき.らか']
# 2119                 NaN                                             ['ロウ']
# 2120                 NaN                                             ['ロウ']
# 2121              ['ロウ']                                           ['たかどの']
# 2122              ['ロウ']                            ['も.る', 'も.れる', 'も.らす']
# 2123         ['ロウ', 'ル']                      ['かご', 'こ.める', 'こも.る', 'こ.む']
# 2124        ['ロク', 'リク']                         ['む', 'む.つ', 'むっ.つ', 'むい']
# 2125              ['ロク']                                    ['しる.す', 'と.る']
# 2126              ['ロク']                                            ['ふもと']
# 2127              ['ロン']                                         ['あげつら.う']
# 2128     ['ワ', 'オ', 'カ']       ['やわ.らぐ', 'やわ.らげる', 'なご.む', 'なご.やか', 'あ.える']
# 2129               ['ワ']                                    ['はな.す', 'はなし']
# 2130              ['ワイ']                                          ['まかな.う']
# 2131             ['キョウ']                                       ['わき', 'わけ']
# 2132              ['ワク']                                           ['まど.う']
# 2133                 NaN                                             ['わく']
# 2134              ['ワン']                                            ['いりえ']
# 2135              ['ワン']                                             ['うで']
#
#                                   on_readings_compounds  ...  \
# 0     ['亜  【ア】  sub-, -ous (indicating a low oxidati...  ...
# 1     ['哀悼  【アイトウ】  condolence, regret, tribute, sor...  ...
# 2     ['挨拶  【アイサツ】  greeting, greetings, salutation,...  ...
# 3     ['愛  【アイ】  love, affection, care, attachment, ...  ...
# 4     ['曖昧  【アイマイ】  vague, ambiguous, unclear, fuzzy...  ...
# 5     ['悪  【アク】  evil, wickedness', '悪質  【アクシツ】  mal...  ...
# 6     ['握手  【アクシュ】  handshake', '握力  【アクリョク】  grip (...  ...
# 7     ['圧  【アツ】  pressure, force', '圧力  【アツリョク】  pre...  ...
# 8     ['扱い  【あつかい】  treatment, service', '扱い方  【あつかい...  ...
# 9     ['宛然  【エンゼン】  as if, the very thing itself', '...  ...
# 10    ['嵐気  【ランキ】  mountain mist, mountain air', '青嵐...  ...
# 11    ['安価  【アンカ】  low-priced, cheap, inexpensive, s...  ...
# 12    ['案  【アン】  idea, plan, proposal, suggestion, (...  ...
# 13    ['暗黒  【アンコク】  darkness', '暗雲  【アンウン】  dark clo...  ...
# 14    ['以降  【イコウ】  on and after, as from, hereafter,...  ...
# 15    ['衣  【キヌ】  clothing, garment, dress', '衣装  【イシ...  ...
# 16    ['位  【イ】  rank, place (e.g. first place), deci...  ...
# 17    ['囲碁  【イゴ】  go, board game of capturing territ...  ...
# 18    ['医  【イ】  medicine, the healing art, healing, ...  ...
# 19    ['依然  【イゼン】  still, as yet, as it has been', '...  ...
# 20    ['委員  【イイン】  committee member', '委員会  【イインカイ】 ...  ...
# 21    ['威  【イ】  power, authority, might, influence, ...  ...
# 22    ['為政者  【イセイシャ】  statesman, administrator, poli...  ...
# 23    ['畏怖  【イフ】  awe, fear, fright', '畏敬  【イケイ】  re...  ...
# 24    ['胃  【イ】  stomach, Chinese "stomach" constella...  ...
# 25    ['尉官  【イカン】  officer below the rank of major, ...  ...
# 26    ['異  【イ】  difference (of opinion), strange, od...  ...
# 27    ['移行  【イコウ】  switching over to, migration, tra...  ...
# 28    ['萎縮  【イシュク】  withering, shrivelling, shrinkin...  ...
# 29    ['偉  【イ】  greatness', '偉業  【イギョウ】  great achie...  ...
# ...                                                 ...  ...
# 2106  ['廉  【レン】  cheap, inexpensive', '廉価  【レンカ】  lo...  ...
# 2107  ['練習  【レンシュウ】  practice, practising', '練達  【レン...  ...
# 2108  ['錬金術師  【レンキンジュツシ】  alchemist', '錬金術  【レンキンジュツ...  ...
# 2109  ['呂律  【ロレツ】  articulation', 'ろれつが回らない  【ロレツガマワ...  ...
# 2110  ['炉  【ロ】  hearth, fireplace, furnace, kiln', '...  ...
# 2111                                ['貨賂  【カロ】  bribe']  ...
# 2112  ['路上  【ロジョウ】  (on the) road, (on the) way, (in...  ...
# 2113  ['露  【ロ】  Russia', '露骨  【ロコツ】  open, unconceal...  ...
# 2114  ['老  【ロウ】  old age, age, old people, the old, ...  ...
# 2115  ['労  【ロウ】  labor, labour, toil, trouble, pains...  ...
# 2116  ['弄火  【ロウカ】  playing with fire, flirting', '弄花...  ...
# 2117  ['郎君  【ロウクン】  young lord, young nobleman', '郎党...  ...
# 2118  ['朗報  【ロウホウ】  good news', '朗読  【ロウドク】  reading...  ...
# 2119  ['浪  【ロウ】  person who has spent X years after ...  ...
# 2120  ['廊  【ロウ】  corridor, passage, hall', '廊下  【ロウカ...  ...
# 2121  ['楼  【ロウ】  tower, tall building, turret, looko...  ...
# 2122  ['漏洩  【ロウエイ】  leak (of secrets, information, e...  ...
# 2123  ['籠球  【ロウキュウ】  basketball', '籠居  【ロウキョ】  stayi...  ...
# 2124  ['六  【ロク】  six', '６月  【ロクガツ】  June, sixth mont...  ...
# 2125  ['録  【ロク】  record, transcript', '録音  【ロクオン】  (...  ...
# 2126  ['山麓  【サンロク】  foot of a mountain, base of a mo...  ...
# 2127  ['論  【ロン】  argument, discussion, dispute, cont...  ...
# 2128  ['和  【ワ】  sum, harmony, peace, Japan, Japanese...  ...
# 2129  ['話  【ワ】  counter for stories, episodes of TV ...  ...
# 2130  ['賄賂  【ワイロ】  bribe, sweetener, douceur', '斡旋収賄...  ...
# 2131  ['脇侍  【ワキジ】  flanking image (e.g. in a Buddha ...  ...
# 2132  ['惑星  【ワクセイ】  planet', '惑星科学  【ワクセイカガク】  plane...  ...
# 2133  ['枠  【わく】  frame, framework, border, box, limi...  ...
# 2134  ['湾  【ワン】  bay, gulf, inlet', '湾岸  【ワンガン】  gul...  ...
# 2135  ['腕力  【ワンリョク】  physical strength, brute streng...  ...
#
#      Rank of Appearances on Twitter Number of Appearances on Wikipedia  \
# 0                            1391.0                           172858.0
# 1                            1307.0                            19390.0
# 2                            1292.0                            12111.0
# 3                              56.0                           754387.0
# 4                            2068.0                           116055.0
# 5                             131.0                           258354.0
# 6                            1078.0                            39886.0
# 7                             902.0                           169022.0
# 8                            1251.0                           173755.0
# 9                            2263.0                            11860.0
# 10                           1266.0                            55865.0
# 11                            170.0                           709012.0
# 12                            653.0                           292745.0
# 13                            999.0                           103843.0
# 14                            236.0                          1434858.0
# 15                            895.0                           119240.0
# 16                            225.0                          1487156.0
# 17                            832.0                           216878.0
# 18                            836.0                           369915.0
# 19                           1373.0                          1641395.0
# 20                           1314.0                           331428.0
# 21                           1602.0                            65083.0
# 22                            744.0                           224947.0
# 23                           2869.0                             2804.0
# 24                           1100.0                            11894.0
# 25                           2709.0                            46591.0
# 26                            874.0                           357097.0
# 27                            781.0                           618065.0
# 28                            854.0                             2539.0
# 29                           1326.0                            21046.0
# ...                             ...                                ...
# 2106                         2162.0                            17252.0
# 2107                          345.0                           135257.0
# 2108                         2183.0                            25847.0
# 2109                          480.0                            58012.0
# 2110                         2172.0                            25416.0
# 2111                         2539.0                             2046.0
# 2112                          428.0                           899356.0
# 2113                         1275.0                           107781.0
# 2114                          835.0                           144231.0
# 2115                          888.0                           178741.0
# 2116                         1997.0                             6528.0
# 2117                          527.0                           854341.0
# 2118                         1640.0                            74484.0
# 2119                         1075.0                            65884.0
# 2120                         1818.0                            16211.0
# 2121                         2105.0                            20883.0
# 2122                         1384.0                            17741.0
# 2123                         1922.0                            21224.0
